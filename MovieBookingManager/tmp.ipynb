# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.cgv.co.kr/common/showtimes/iframeTheater.aspx?areacode=01&theatercode=0013&date=20211111"
MovieName = '이터널스'
Theater = 'IMAX관'
resp = requests.get(url)
html = resp.text
soup = BeautifulSoup(html, 'html.parser')
lists = soup.select('.col-times')
for i in range(0,len(lists)):
    if MovieName in str(lists[i]) and Theater in str(lists[i]):
        print(MovieName, '가 ', Theater, '으로 뜸!!')
        out1 = lists[i]

        # soup1 = BeautifulSoup(str(out1), 'html.parser')
        # lists1 = soup1.select('.info-timetable')
        # for item in lists1:
        #     # print(item)
        #     if Theater in str(item):

        #         soup2 = BeautifulSoup(str(item), 'html.parser')
        #         lists2 = soup1.select('div.info-timetable > ul > li ')
        #         print(lists2)
# print(out1)
# Out:
# 이터널스 가  IMAX관 으로 뜸!!
# ...
